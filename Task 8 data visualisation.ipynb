# %% [markdown]
# # Ploty
# Plotly is an open-source module of Python that is used for data visualization and supports various graphs like line charts, scatter plots, bar charts, histograms, area plots, etc. Plotly produces interactive graphs, can be embedded on websites, and provides a wide variety of complex plotting options. The graphs and plots are robust, and a wide variety of people can use them.

# %%
#import
import plotly
from plotly import __version__
print (__version__)
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# Out:
# 5.16.1

# %%
#Jupyter setup
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Line chart
# A line chart is majorly used to show how a certain numerical value changes over time or over a certain interval.

# %%
iplot([{"x": [1, 2, 3, 4, 5], "y": [1, 2, 6, 4, 1]}])
# Out:
# <div>                            <div id="ddbac383-7be4-4cd7-92eb-bd1eafaf2b10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddbac383-7be4-4cd7-92eb-bd1eafaf2b10")) {                    Plotly.newPlot(                        "ddbac383-7be4-4cd7-92eb-bd1eafaf2b10",                        [{"x":[1,2,3,4,5],"y":[1,2,6,4,1],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{ ...
#
# var gd = document.getElementById('ddbac383-7be4-4cd7-92eb-bd1eafaf2b10');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }}

# %% [markdown]
# # 2D Histograms or Density Heatmaps
# A 2D histogram, also known as a density heatmap, is the 2-dimensional generalization of a histogram which resembles a heatmap but is computed by grouping a set of points specified by their x and y coordinates. This kind of visualization is often used where showing large data sets as scatter plots would result in points overlapping each other and hiding patterns.

# %%
import plotly.graph_objs as go
import numpy as np

x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y, contours=dict(coloring='heatmap')),
       go.Scatter(x=x, y=y, mode='markers', marker=dict(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div>                            <div id="b2722b9e-a60c-4f9c-b4c1-dd27c9957c22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2722b9e-a60c-4f9c-b4c1-dd27c9957c22")) {                    Plotly.newPlot(                        "b2722b9e-a60c-4f9c-b4c1-dd27c9957c22",                        [{"contours":{"coloring":"heatmap"},"x":[-0.9888483166867494,-0.2642360600340983,0.08268940636297147,-0.20950281683251307,3.0657266882499434,-1.2722797719093621,-0.17155420905492308,-0.06884217950683091,0.102412332109656,1.1069186042923398,0.8626238182278935,0.7950985704361694,0.8958126048648131,0.29445532929313667,-0.983638965181804,0.8533786421418805,-0.8761544827194366,-0.048158814907448805,0.6801651998303769,0.5461493880617558,0.062272166030110786,1.1420863417629286,1.7728196024258234,-0.10185938546625305,-0.09523553420001024,-0.5860985693368089,-0.7651887366744177,-1.6043689818438547,-1.1750007975853014,2.509379516515645,0.9389342174810366,1.1112529723363234,-1.0714346779758832,-1.7084762721543663,0.44310514861545003,0.18868184318760758,-0.1604286773259485,-0.923788292673815,-0.273644705824396,2.153023439027511,-1.1647502666111649,-0.9213456625856098,0.5839078326679702,2.1101705905219847,-1.3575369753019588,-0.46064781205005395,1.6737261547832953,0.8243149277763298,-0.4445298748930947,0.04180083116802835,-0.4259175345926023,1.068595147543763,-1.020230522207812,0.54898927329541,-0.4990498216618868,-2.4309338992026364,-1.2818427813509323,0.10725625396738639,1.9703883767497912,-0.3100837502353381,-0.9250615331407015,0.18319032788649708,0.5073886521533625,0.37994060863943796,-1.5711096374671945,0.9150449450219973,1.030664765643283,2.15097256256998,-1.5254762238030801,-0.5117426827090183,-0.7227125311510406,-0.12726666198756403,-0.696416712512386,0.3226648795045452,1.7177552779314889,-2.10766308323772,-2.2348858967091134,-0.8000694374695198,0.04021837834959285,1.8148688078838502,-1.5260310441917686,0.013538819012210882,0.4451193667921017,0.4436934836331099,1.3243691005121219,0.8101337158074107,-0.5292322439846295,0.7864139185720566,-2.0142869752876775,1.1608593744117177,-0.06954445596089845,-0.6588495031270769,-0.4859541596164225,0.18406794152749142,-1.6361927957640499,-1.9871816642272655,-0.022998473568904557,-0.7505212617298664,1.9365935481994536,-1.87058662847413,0.1915909503960706,1.4618272592788815,0.5523911959930432,0.4045983126676626,2.044193588895856,0.7547858529048129,1.09451314369649,-0.2795440897442881,0.04423133910870236,-0.8311075427433244,1.6091459010321985,0.2100670522621336,-1.6917287239241032,-1.063265087254398,0.47974232766047753,-0.17056847998596275,1.4572629279669769,0.05769229702043225,-0.7182803842069532,0.05525833017937025,0.3659249077557192,1.1382863330465094,-0.4914727927554776,0.2388812553243009,1.3073394528167035,1.3305110357190029,-0.13357551254977615,2.5359347071552056,-1.555131979413512,0.6975116409258325,1.0346736436519024,-2.0964453947640354,-0.6485360030955434,1.1897097337929134,-0.3005672755325606,0.013189969604397585,0.9175903258113287,-1.59096021303869,0.17795836782294988,-0.40895894300814195,-1.1336829741151748,-1.4176176608149462,-0.6615019785118941,0.8025410299119717,-0.7321185733388103,0.7337768942746904,1.0069031310356762,-0.5665627046097053,0.6215082925573616,0.06393931708592153,-0.6935777781167248,0.3459508648789508,2.3032656118301764,-1.6644951949250963,0.9326686195757625,-0.2668095322952982,1.9803198156182868,0.3181647787954934,1.1958765493780317,-1.7480512155735934,1.3524232010105153,0.4607504417460757,-1.407785045959549,1.0381724909458991,0.2531752247164084,1.0448795171531446,0.5315987612075946,1.009590176383708,-0.7953445545562922,-1.4574924381452492,-0.10516077695328646,-0.9786053417130565,0.8065770689702698,-0.18520655172570577,-2.119685233683582,1.646941572 ...

# %% [markdown]
# # Histogram
# A histogram plots the continuous distribution of variable as series of bars and each bar indicates the frequency of the occurring value in a variable. In order to use a histogram, we simply require a variable that takes continuous numeric values

# %% [markdown]
# # Scatter plot
# Scatter plot represent values for two different numeric variables. They are mainly used for the representation of the relationship between two variables

# %%
from chart_studio import plotly
import plotly.graph_objs as go
import numpy as np

# %%
N = 100
example_x = np.random.rand(N)
example_y = np.random.rand(N)

# %%
trace = go.Scatter(
    x = example_x,
    y = example_y,
    mode = 'markers')

# %%
data = [trace]
iplot(data)
# Out:
# <div>                            <div id="f2722e7e-bcd0-4892-8be1-49979a0f5bdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f
# %% [markdown]
# # Pie chart
# A pie chart represents the distribution of different variables among total. In the pie chart each slice shows its contribution to the total amount.

# %%
#Expenses

#breakdown each category 
groups = ['Rent','Food','Bills','Miscellaneous']
#create amount
amount = [1000,518,331,277]
#style
colors = ['aqua', '#f9b1ee', '#b7f9b1',  '#9467bd']

trace = go.Pie(labels=groups, values=amount,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=25),
               marker=dict(colors=colors, 
                           line=dict(color='#000000', width=2)))

#plot - 
iplot([trace])
# Out:
# <div>                            <div id="1e5cf8f8-42b9-4d87-9fa2-0839bfbd87ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e5cf8f8-42b9-4d87-9fa2-0839bfbd87ec")) {                    Plotly.newPlot(                        "1e5cf8f8-42b9-4d87-9fa2-0839bfbd87ec",                        [{"hoverinfo":"label+percent","labels":["Rent","Food","Bills","Miscellaneous"],"marker":{"colors":["aqua","#f9b1ee","#b7f9b1","#9467bd"],"line":{"color":"#000000","width":2}},"textfont":{"size":25},"textinfo":"value","values":[1000,518,331,277],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scat ...
#
# var gd = document.getElementById('1e5cf8f8-42b9-4d87-9fa2-0839bfbd87ec');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display

# %% [markdown]
# # Custom data usage

# %%
import pandas as pd
pubg = pd.read_csv('PUBG.csv')
#pubg.head(10)
df_pubg = pubg.apply(pd.to_numeric, errors='ignore')
df_new_pubg = df_pubg.head(10)

# %%
#df_new_pubg.head(10)

# %%
trace = go.Scatter(x = df_new_pubg['solo_RoundsPlayed'], y= df_new_pubg['solo_Wins'],
                  name ='Rounds Won')
layout = go.Layout(title='PUBG Wins vs Rounds Played',
                   plot_bgcolor='rgb(230, 230,230)', 
                   showlegend=True)
fig = go.Figure(data=[trace], layout=layout)

iplot(fig, filename='test')
# Out:
# <div>                            <div id="ca7129ed-4e0d-4cb7-90f1-834e3b521471" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca7129ed-4e0d-4cb7-90f1-834e3b521471")) {                    Plotly.newPlot(                        "ca7129ed-4e0d-4cb7-90f1-834e3b521471",                        [{"name":"Rounds Won","x":[17,33,5,8,6,16,142,19,44,8],"y":[3,6,0,4,2,5,12,5,6,2],"type":"scatter"}],                        {"plot_bgcolor":"rgb(230, 230,230)","showlegend":true,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"sca ...
#
# var gd = document.getElementById('ca7129ed-4e0d-4cb7-90f1-834e3b521471');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display

# %%
df_bar_pubg = df_pubg.head(30)
trace1 = go.Bar( 
        x = df_bar_pubg['player_name'],
        y = df_bar_pubg['solo_RoundsPlayed'],
        name= 'Rounds Played')

trace2 = go.Bar( 
        x = df_bar_pubg['player_name'],
        y = df_bar_pubg['solo_Wins'],
        name= 'Wins')

# %%
data = [trace1, trace2]
layout = go.Layout(barmode='group')

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>                            <div id="ef29dec9-87d9-4d0c-9aca-927e5035e262" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef29dec9-87d9-4d0c-9aca-927e5035e262")) {                    Plotly.newPlot(                        "ef29dec9-87d9-4d0c-9aca-927e5035e262",                        [{"name":"Rounds Played","x":["BreakNeck","Blackwalk","mercedes_benz","DORA","n2tstar","coldoxygen","Giken","KoreaNo1","undor","Fordune","PandaTV-Tongk","Benny-_-","PanDaTV_Karl","homeboye","YUPPIEE","Doomhammer","DinghisKhan","YoonRoot","3N1GmA","synthtail","SevenWolf","FZTEAMLDS","1125","BombBurst","SILPHTV","SexyPIG","TOP_94","zeggi","baoli6666666","Toadoo1"],"y":[17,33,5,8,6,16,142,19,44,8,116,335,87,72,23,3,165,65,16,45,55,45,9,14,277,265,77,52,56,22],"type":"bar"},{"name":"Wins","x":["BreakNeck","Blackwalk","mercedes_benz","DORA","n2tstar","coldoxygen","Giken","KoreaNo1","undor","Fordune","PandaTV-Tongk","Benny-_-","PanDaTV_Karl","homeboye","YUPPIEE","Doomhammer","DinghisKhan","YoonRoot","3N1GmA","synthtail","SevenWolf","FZTEAMLDS","1125","BombBurst","SILPHTV","SexyPIG","TOP_94","zeggi","baoli6666666","Toadoo1"],"y":[3,6,0,4,2,5,12,5,6,2,7,4,9,4,3,1,38,12,6,2,7,4,3,2,48,63,4,3,3,2],"type":"bar"}],                        {"barmode":"group","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...

# %% [markdown]
# # 2-D Plot

# %%
df_bar_pubg.head(10)
# Out:
#      player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0      BreakNeck        4405                 3.14          17.65
# 1      Blackwalk        8199                 4.41          18.18
# 2  mercedes_benz        4454                 3.60           0.00
# 3           DORA        7729                14.00          50.00
# 4        n2tstar           0                10.50          33.33
# 5     coldoxygen       33313                 5.73          31.25
# 6          Giken       15585                 2.45           8.45
# 7       KoreaNo1        9454                 2.71          26.32
# 8          undor       24029                 3.68          13.64
# 9        Fordune       11289                 4.17          25.00
#
#    solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# 0           18469.14                 17          3                0.83
# 1           33014.86                 33          6                0.36
# 2            4330.44                  5          0                0.00
# 3           13421.82                  8          4                0.67
# 4            9841.04                  6          2                0.40
# 5           22003.22                 16          5                0.50
# 6          148051.25                142         12                0.18
# 7           26091.14                 19          5                0.50
# 8           49282.41                 44          6                0.23
# 9           10280.77                  8          2                0.25
#
#    solo_Top10s  solo_Top10Ratio  ...  squad_RideDistance  squad_MoveDistance  \
# 0            4             23.5  ...          3751590.99          5194786.58
# 1           11             33.3  ...          4295917.30          6051783.67
# 2            1             20.0  ...          3935265.63          5589608.74
# 3            6             75.0  ...          2738998.00          3796916.00
# 4            5             83.3  ...          2347295.00          3220260.00
# 5           10             62.5  ...          3218436.00          4733977.00
# 6           34             23.9  ...          2057423.12          2883099.31
# 7           10             52.6  ...          3586593.00          4854387.00
# 8           13             29.5  ...          1054263.00          1550975.00
# 9            4             50.0  ...          2793909.91          4071039.87
#
#    squad_AvgWalkDistance  squad_AvgRideDistance  squad_LongestKill  \
# 0                2626.97                4372.64             536.98
# 1                2422.48                6009.73             734.85
# 2                1871.89                3011.87             725.44
# 3                2154.62                5578.41             587.28
# 4                2098.47                5642.54             546.10
# 5                2078.93                4414.86            1212.76
# 6                1664.77                3022.51             564.20
# 7                1635.86                4627.86             806.24
# 8                2207.61                4685.61             455.67
# 9                1981.29                3635.28             546.95
#
#    squad_Heals  squad_Revives  squad_Boosts  squad_DamageDealt  squad_DBNOs
# 0         2186            234          1884          242132.73         1448
# 1         2041            276          2340          269795.75         1724
# 2         1766            210          2193          292977.07         1897
# 3         1214            142          1252          181106.90         1057
# 4         1245            120           923          160029.80         1077
# 5         2023            195          2307          238640.00         1450
# 6         1274            133          1320          132008.88          775
# 7         2199            163          1864          201659.00         1287
# 8          617             61           585           80498.73          513
# 9         1320            220          1338          123573.74          675
#
# [10 rows x 152 columns]

# %%
import plotly.figure_factory as ff

x = df_bar_pubg['solo_Wins']
y = df_bar_pubg['solo_TimeSurvived']
#z = df_bar_pubg['squad_Heals']
# This line defines a custom colorscale that will be used for the density plot.
# A colorscale determines the colors used to represent the density values in the plot.
colorscale = ['#7A4579', '#D56073', 'rgb(236,158,105)', (1, 1, 0.2), (0.98,0.98,0.98)]
# hist_color: This parameter sets the color of the histogram bins in the plot.
# point_size: This parameter determines the size of the data points in the plot.
fig = ff.create_2d_density(
    x, y, colorscale=colorscale,
    hist_color='rgb(255, 237, 222)', point_size=3
)


iplot(fig, filename='histogram_subplots')
# Out:
# <div>                            <div id="198e61d8-31b2-493e-9f9e-c84d2279637e" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("198e61d8-31b2-493e-9f9e-c84d2279637e")) {                    Plotly.newPlot(                        "198e61d8-31b2-493e-9f9e-c84d2279637e",                        [{"marker":{"color":"rgb(0, 0, 128)","opacity":0.4,"size":3},"mode":"markers","name":"points","x":[3,6,0,4,2,5,12,5,6,2,7,4,9,4,3,1,38,12,6,2,7,4,3,2,48,63,4,3,3,2],"y":[18469.14,33014.86,4330.44,13421.82,9841.04,22003.22,148051.25,26091.14,49282.41,10280.77,106330.23,232995.54,91380.4,71910.46,30996.86,3638.01,246771.12,87214.43,20927.23,45916.37,62763.42,43124.07,11733.19,18488.62,331173.26,397022.2,87514.41,53548.14,47966.09,25094.18],"type":"scatter"},{"colorscale":[[0.0,"rgb(122, 69, 121)"],[0.25,"rgb(213, 96, 115)"],[0.5,"rgb(236, 158, 105)"],[0.75,"rgb(255, 255, 51)"],[1.0,"rgb(250, 250, 250)"]],"name":"density","ncontours":20,"reversescale":true,"showscale":false,"x":[3,6,0,4,2,5,12,5,6,2,7,4,9,4,3,1,38,12,6,2,7,4,3,2,48,63,4,3,3,2],"y":[18469.14,33014.86,4330.44,13421.82,9841.04,22003.22,148051.25,26091.14,49282.41,10280.77,106330.23,232995.54,91380.4,71910.46,30996.86,3638.01,246771.12,87214.43,20927.23,45916.37,62763.42,43124.07,11733.19,18488.62,331173.26,397022.2,87514.41,53548.14,47966.09,25094.18],"type":"histogram2dcontour"},{"marker":{"color":"rgb(255, 237, 222)"},"name":"x density","x":[3,6,0,4,2,5,12,5,6,2,7,4,9,4,3,1,38,12,6,2,7,4,3,2,48,63,4,3,3,2],"yaxis":"y2","type":"histogram"},{"marker":{"color":"rgb(255, 237, 222)"},"name":"y density","xaxis":"x2","y":[18469.14,33014.86,4330.44,13421.82,9841.04,22003.22,148051.25,26091.14,49282.41,10280.77,106330.23,232995.54,91380.4,71910.46,30996.86,3638.01,246771.12,87214.43,20927.23,45916.37,62763.42,43124.07,11733.19,18488.62,331173.26,397022.2,87514.41,53548.14,47966.09,25094.18],"type":"histogram"}],                        {"autosize":false,"bargap":0,"height":600,"hovermode":"closest","margin":{"t":50},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %% [markdown]
# # 3-D Plot visualisation
# Plotly Express is the easy-to-use, high-level interface to Plotly, which operates on a variety of types of data and produces easy-to-style figures. Like the 2D scatter plot px.scatter, the 3D function px.scatter_3d plots individual data in three-dimensional space.

# %%
df_bar_pubg.head(1)
# Out:
#   player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0   BreakNeck        4405                 3.14          17.65
#
#    solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# 0           18469.14                 17          3                0.83
#
#    solo_Top10s  solo_Top10Ratio  ...  squad_RideDistance  squad_MoveDistance  \
# 0            4             23.5  ...          3751590.99          5194786.58
#
#    squad_AvgWalkDistance  squad_AvgRideDistance  squad_LongestKill  \
# 0                2626.97                4372.64             536.98
#
#    squad_Heals  squad_Revives  squad_Boosts  squad_DamageDealt  squad_DBNOs
# 0         2186            234          1884          242132.73         1448
#
# [1 rows x 152 columns]

# %%
import plotly.express as px

# color='player_name': This parameter assigns colors to the data points based on the 'player_name' column in the DataFrame.
# Each unique 'player_name' will have a different color.
# symbol='squad_Assists': This parameter assigns different symbols (markers) to the data points based on the 'squad_Assists' column in the DataFrame.
# Different values of 'squad_Assists' will result in different marker symbols.

fig = px.scatter_3d(df_bar_pubg, x='solo_Wins', y='solo_TimeSurvived', z='solo_RoundsPlayed',
                    color='player_name', symbol='squad_Assists')
fig.show()
# Out:
# <div>                            <div id="d1c45333-496c-45a3-9f6f-cbec756f32bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1c45333-496c-45a3-9f6f-cbec756f32bf")) {                    Plotly.newPlot(                        "d1c45333-496c-45a3-9f6f-cbec756f32bf",                        [{"hovertemplate":"player_name=BreakNeck\u003cbr\u003esquad_Assists=892\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BreakNeck, 892","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"BreakNeck, 892","scene":"scene","showlegend":true,"x":[3],"y":[18469.14],"z":[17],"type":"scatter3d"},{"hovertemplate":"player_name=Blackwalk\u003cbr\u003esquad_Assists=964\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Blackwalk, 964","marker":{"color":"#EF553B","symbol":"diamond"},"mode":"markers","name":"Blackwalk, 964","scene":"scene","showlegend":true,"x":[6],"y":[33014.86],"z":[33],"type":"scatter3d"},{"hovertemplate":"player_name=mercedes_benz\u003cbr\u003esquad_Assists=965\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mercedes_benz, 965","marker":{"color":"#00cc96","symbol":"square"},"mode":"markers","name":"mercedes_benz, 965","scene":"scene","showlegend":true,"x":[0],"y":[4330.44],"z":[5],"type":"scatter3d"},{"hovertemplate":"player_name=DORA\u003cbr\u003esquad_Assists=659\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DORA, 659","marker":{"color":"#ab63fa","symbol":"x"},"mode":"markers","name":"DORA, 659","scene":"scene","showlegend":true,"x":[4],"y":[13421.82],"z":[8],"type":"scatter3d"},{"hovertemplate":"player_name=n2tstar\u003cbr\u003esquad_Assists=490\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"n2tstar, 490","marker":{"color":"#FFA15A","symbol":"cross"},"mode":"markers","name":"n2tstar, 490","scene":"scene","showlegend":true,"x":[2],"y":[9841.04],"z":[6],"type":"scatter3d"},{"hovertemplate":"player_name=coldoxygen\u003cbr\u003esquad_Assists=737\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"coldoxygen, 737","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"coldoxygen, 737","scene":"scene","showlegend":true,"x":[5],"y":[22003.22],"z":[16],"type":"scatter3d"},{"hovertemplate":"player_name=Giken\u003cbr\u003esquad_Assists=436\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Giken, 436","marker":{"color":"#FF6692","symbol":"diamond"},"mode":"markers","name":"Giken, 436","scene":"scene","showlegend":true,"x":[12],"y":[148051.25],"z":[142],"type":"scatter3d"},{"hovertemplate":"player_name=KoreaNo1\u003cbr\u003esquad_Assists=627\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlayed=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KoreaNo1, 627","marker":{"color":"#B6E880","symbol":"square"},"mode":"markers","name":"KoreaNo1, 627","scene":"scene","showlegend":true,"x":[5],"y":[26091.14],"z":[19],"type":"scatter3d"},{"hovertemplate":"player_name=undor\u003cbr\u003esquad_Assists=255\u003cbr\u003esolo_Wins=%{x}\u003cbr\u003esolo_TimeSurvived=%{y}\u003cbr\u003esolo_RoundsPlaye ...

# %% [markdown]
# # Time series
# Time series data is data that is collected or recorded over a sequence of equally spaced time intervals. It offers features like line charts, annotations, interactivity, custom date and time formatting, support for multiple time series on a single plot or in subplots, animations, and range selection, making it a valuable tool for exploring.

# %%
from chart_studio import plotly
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv")

data = [go.Scatter(
          x=df.Date,
          y=df['AAPL.Close'])]
#This line creates a list called data, which contains a single element.
#It specifies the x-axis data as the 'Date' column from the DataFrame df and the y-axis data as the 'AAPL.Close' column, which represents the closing prices of Apple's stock.

iplot(data)
# Out:
# <div>                            <div id="410b1ffd-b8ae-4a5d-88c0-5b88d7b3d002" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("410b1ffd-b8ae-4a5d-88c0-5b88d7b3d002")) {                    Plotly.newPlot(                        "410b1ffd-b8ae-4a5d-88c0-5b88d7b3d002",                        [{"x":["2015-02-17","2015-02-18","2015-02-19","2015-02-20","2015-02-23","2015-02-24","2015-02-25","2015-02-26","2015-02-27","2015-03-02","2015-03-03","2015-03-04","2015-03-05","2015-03-06","2015-03-09","2015-03-10","2015-03-11","2015-03-12","2015-03-13","2015-03-16","2015-03-17","2015-03-18","2015-03-19","2015-03-20","2015-03-23","2015-03-24","2015-03-25","2015-03-26","2015-03-27","2015-03-30","2015-03-31","2015-04-01","2015-04-02","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-18","2015-05-19","2015-05-20","2015-05-21","2015-05-22","2015-05-26","2015-05-27","2015-05-28","2015-05-29","2015-06-01","2015-06-02","2015-06-03","2015-06-04","2015-06-05","2015-06-08","2015-06-09","2015-06-10","2015-06-11","2015-06-12","2015-06-15","2015-06-16","2015-06-17","2015-06-18","2015-06-19","2015-06-22","2015-06-23","2015-06-24","2015-06-25","2015-06-26","2015-06-29","2015-06-30","2015-07-01","2015-07-02","2015-07-06","2015-07-07","2015-07-08","2015-07-09","2015-07-10","2015-07-13","2015-07-14","2015-07-15","2015-07-16","2015-07-17","2015-07-20","2015-07-21","2015-07-22","2015-07-23","2015-07-24","2015-07-27","2015-07-28","2015-07-29","2015-07-30","2015-07-31","2015-08-03","2015-08-04","2015-08-05","2015-08-06","2015-08-07","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015-09-04","2015-09-08","2015-09-09","2015-09-10","2015-09-11","2015-09-14","2015-09-15","2015-09-16","2015-09-17","2015-09-18","2015-09-21","2015-09-22","2015-09-23","2015-09-24","2015-09-25","2015-09-28","2015-09-29","2015-09-30","2015-10-01","2015-10-02","2015-10-05","2015-10-06","2015-10-07","2015-10-08","2015-10-09","2015-10-12","2015-10-13","2015-10-14","2015-10-15","2015-10-16","2015-10-19","2015-10-20","2015-10-21","2015-10-22","2015-10-23","2015-10-26","2015-10-27","2015-10-28","2015-10-29","2015-10-30","2015-11-02","2015-11-03","2015-11-04","2015-11-05","2015-11-06","2015-11-09","2015-11-10","2015-11-11","2015-11-12","2015-11-13","2015-11-16","2015-11-17","2015-11-18","2015-11-19","2015-11-20","2015-11-23","2015-11-24","2015-11-25","2015-11-27","2015-11-30","2015-12-01","2015-12-02","2015-12-03","2015-12-04","2015-12-07","2015-12-08","2015-12-09","2015-12-10","2015-12-11","2015-12-14","2015-12-15","2015-12-16","2015-12-17","2015-12-18","2015-12-21","2015-12-22","2015-12-23","2015-12-24","2015-12-28","2015-12-29","2015-12-30","2015-12-31","2016-01-04","2016-01-05","2016-01-06","2016-01-07","2016-01-08","2016-01-11","2016-01-12","2016-01-13","2016-01-14","2016-01-15","2016-01-19","2016-01-20","2016-01-21","2016-01-22","2016-01-25","2016-01-26","2016-01-27","2016-01-28","2016-01-29","2016-02-01","2016-02-02","2016-02-03","2016-02-04","2016-02-05","2016-02-08","2016-02-09","2016-02-10","2016-02-11","2016-02-12","2016-02-16","2016-02-17","2016-02-18","2016-02-19","2016-02-22","2016-02-23","2016-02-24","2016-02-25","2016-02-26","2016-02-29","2016-03-01","2016-03-02","2016-03-03","2016-03-04","2016-03-07","2016 ...

# %%
#enter the data
tesla = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/tesla-stock-price.csv")

# running two scatter plots together to comapre how the stock prices work in high and low state
trace_one = go.Scatter(
            x=tesla.date,
            y=tesla['high'],
            name= "Tesla High",#just to initialise the scatter plot 1
            line = dict(color='#17BECF'),
            opacity = 0.8)

trace_two = go.Scatter(
            x=tesla.date,
            y=tesla['low'],
            name= "Tesla Low",#scatter plot 2
            line = dict(color='#7F7F7F'),
            opacity = 0.8)

data = [trace_one, trace_two]

#customizing our loyout
layout = dict(
        title = 'Tesla Stock Price - High vs Low')

#buliding our figure
fig = dict(data=data, layout=layout)
iplot(fig, filename = 'Tesla Stock Comparison')
# Out:
# <div>                            <div id="8752fdad-e4af-476e-b316-137d7ce81925" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8752fdad-e4af-476e-b316-137d7ce81925")) {                    Plotly.newPlot(                        "8752fdad-e4af-476e-b316-137d7ce81925",                        [{"line":{"color":"#17BECF"},"name":"Tesla High","opacity":0.8,"x":["11:34","2018\u002f10\u002f15","2018\u002f10\u002f12","2018\u002f10\u002f11","2018\u002f10\u002f10","2018\u002f10\u002f09","2018\u002f10\u002f08","2018\u002f10\u002f05","2018\u002f10\u002f04","2018\u002f10\u002f03","2018\u002f10\u002f02","2018\u002f10\u002f01","2018\u002f09\u002f28","2018\u002f09\u002f27","2018\u002f09\u002f26","2018\u002f09\u002f25","2018\u002f09\u002f24","2018\u002f09\u002f21","2018\u002f09\u002f20","2018\u002f09\u002f19","2018\u002f09\u002f18","2018\u002f09\u002f17","2018\u002f09\u002f14","2018\u002f09\u002f13","2018\u002f09\u002f12","2018\u002f09\u002f11","2018\u002f09\u002f10","2018\u002f09\u002f07","2018\u002f09\u002f06","2018\u002f09\u002f05","2018\u002f09\u002f04","2018\u002f08\u002f31","2018\u002f08\u002f30","2018\u002f08\u002f29","2018\u002f08\u002f28","2018\u002f08\u002f27","2018\u002f08\u002f24","2018\u002f08\u002f23","2018\u002f08\u002f22","2018\u002f08\u002f21","2018\u002f08\u002f20","2018\u002f08\u002f17","2018\u002f08\u002f16","2018\u002f08\u002f15","2018\u002f08\u002f14","2018\u002f08\u002f13","2018\u002f08\u002f10","2018\u002f08\u002f09","2018\u002f08\u002f08","2018\u002f08\u002f07","2018\u002f08\u002f06
# %%
import plotly.express as px
import pandas as pd
# necessary libraries, plotly.express and pandas, to create a scatter map of earthquake data from the USGS.



# used to read the earthquake data from the USGS website and store it in a pandas DataFrame called data.
data = pd.read_csv('all_month.csv')


# Drop rows with missing or invalid values in the 'mag' column
data = data.dropna(subset=['mag'])
data = data[data.mag >= 0]


# Create scatter map with earthquake data  
#lat and lon parameters specify the latitude and longitude columns in the DataFrame, respectively.
#hover_name parameter specifies the column to display when hovering over a marker, in this case the 'place' column
fig = px.scatter_geo(data, lat='latitude', lon='longitude', color='mag',
                     hover_name='place', #size='mag',
                       title='Earthquakes Around the World')
# used to display the scatter map
fig.show()
# Out:
# <div>                            <div id="c1d6f2c7-b9b7-4cfe-ac0a-c12a9ac8c184" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1d6f2c7-b9b7-4cfe-ac0a-c12a9ac8c184")) {                    Plotly.newPlot(                        "c1d6f2c7-b9b7-4cfe-ac0a-c12a9ac8c184",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cbr\u003emag=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["9 km ENE of P\u0101hala, Hawaii","0 km W of P\u0101hala, Hawaii","8 km E of P\u0101hala, Hawaii","Kermadec Islands region","90 km N of Tatsug\u014d, Japan","Southern Alaska","98 km SSE of Nikolai, Alaska","1 km SW of Parkfield, CA","43 km SW of Harding-Birch Lakes, Alaska","5 km E of Round Mountain, CA","2 km WSW of Lake Henshaw, CA","5 km E of Round Mountain, CA","42 km W of Tyonek, Alaska","76 km WNW of Nikiski, Alaska","13 km NNW of Ferry, Alaska","9 km ENE of P\u0101hala, Hawaii","Island of Hawaii, Hawaii","12 km NNW of Ferry, Alaska","4 km S of Salinas, Puerto Rico","44 km ENE of Ensenada, B.C., MX","115 km SSW of Sand Point, Alaska","31 km WNW of Beluga, Alaska","8 km NW of The Geysers, CA","7 km NW of The Geysers, CA","184 km NW of Neiafu, Tonga","Central Alaska","36 km SW of Atka, Alaska","Dominican Republic region","24 km NNW of G\u00fciria, Venezuela","103 km N of Charlotte Amalie, U.S. Virgin Islands","41 km SSW of Ollag\u00fce, Chile","86 km NW of Karluk, Alaska","18 km SSW of Ludlow, CA","19 km ENE of Sterling, Alaska","16 km NE of West Yellowstone, Montana","100 km NNW of Ternate, Indonesia","6 km SW of Volcano, Hawaii","84 km NW of Karluk, Alaska","87 km NW of Karluk, Alaska","50 km SW of Andalgal\u00e1, Argentina","1 km NE of The Geysers, CA","6 km NNE of Fontana, CA","15 km NW of Parkfield, CA","15 km NW of Coso Junction, CA","34 km SE of Mina, Nevada","42 km SE of Denali National Park, Alaska","36 km E of Cruz Bay, U.S. Virgin Islands","39 km N of Punta Cana, Dominican Republic","Southern Alaska","7 km SW of Volcano, Hawaii","10 km SSW of Volcano, Hawaii","4 km WSW of Aguanga, CA","Morocco","9 km SSE of Idyllwild, CA","Galapagos Triple Junction region","Southern Texas","18 km S of Progreso, B.C., MX","Near the coast of Coquimbo, Chile","7 km SW of Volcano, Hawaii","18 km NNW of Atka, Alaska","3 km ESE of The Geysers, CA","Molucca Sea","47 km S of Glacier View, Alaska","Southern Alaska","4 km SSE of Salinas, Puerto Rico","1 km NE of The Geysers, CA","7 km SW of Volcano, Hawaii","5 km SW of Volcano, Hawaii","24 km SSW of Wales, Alaska","13 km WSW of Searles Valley, CA","86 km NW of Tobelo, Indonesia","6 km SW of Volcano, Hawaii","99 km NNW of Tatsug\u014d, Japan","6 km NW of Cobb, CA","4 km N of Yucca Valley, CA","17 km SSW of Oasis, CA","7 km WSW of Walker, CA","18 km ESE of Anza, CA","7 km ESE of La Parguera, Puerto Rico","6 km SW of Volcano, Hawaii","7 km SW of Volcano, Hawaii","136 km E of Madang, Papua New Guinea","1 km SSW of Magas Arriba, Puerto Rico","43 km NE of Punta Cana, Dominican Republic","13 km SW of Weston, Colorado","Illinois-Indiana border region","2 km WNW of Tanaina, Alaska","Island of Hawaii, Hawaii","201 km NNE of Shi Yomi, India","2 km NW of Frazier Park, CA","8 km ESE of P\u0101hala, Hawaii","7 km SW of Volcano, Hawaii","6 km NW of Meadow Lakes, Alaska","24 km WSW of Ocotillo Wells, CA","Island of Hawaii, Hawaii","9 km SW of Volcano, Hawaii","10 km ENE of Mecca, CA","3 km SE of The Geysers, CA","4 km SSW of Brawley, CA","65 km WSW of Nanwalek, Alaska","4 km SW of Volcano, Hawaii","55 km S of Silver Peak, Nevada","153 km N of Cruz Bay, U.S. Virgin Islands","5 km WSW of Half Moon Bay, CA","3 km SSE of Lima, Montana","11 km ENE of P\u0101 ...

# %% [markdown]
# # Choropleth maps
# A choropleth map is a type of map that uses different colors or shades to represent data values in different regions, such as countries, states, or provinces. In a choropleth map, each region is colored according to the value of a specific data variable, such as population, income, or temperature.
#
# Each region is shaded or colored according to the value of a specific data variable, such as population density, average income, or unemployment rate.

# %%
#imports the necessary libraries, plotly.express and pandas, to create a choropleth map.
import plotly.express as px
import pandas as pd

# Import data from GitHub and reads in data from a CSV file 
data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_with_codes.csv')

# Create basic choropleth map
# px.chloropeth is used to create the choropleth map
fig = px.choropleth(data, locations='iso_alpha', color='gdpPercap', hover_name='country',
                    projection='natural earth', animation_frame='year',
                    title='GDP per Capita by Country')
# data parameter specifies the data to be used, while locations specifies the column in the data 
#hover_name parameter specifies the column in the data that contains the country names
#projection parameter specifies the type of map projection to use


#to display the map
fig.show()
# Out:
# <div>                            <div id="f9911f82-6954-4887-8779-393d68149ca7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9911f82-6954-4887-8779-393d68149ca7")) {                    Plotly.newPlot(                        "f9911f82-6954-4887-8779-393d68149ca7",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=1952\u003cbr\u003eiso_alpha=%{location}\u003cbr\u003egdpPercap=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","